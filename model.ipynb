# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sb

df_train=pd.read_csv('Train_data.csv')
df_train
# Out:
#        duration protocol_type   service  flag  src_bytes  dst_bytes  land  \
# 0             0           tcp  ftp_data    SF        491          0     0
# 1             0           udp     other    SF        146          0     0
# 2             0           tcp   private    S0          0          0     0
# 3             0           tcp      http    SF        232       8153     0
# 4             0           tcp      http    SF        199        420     0
# ...         ...           ...       ...   ...        ...        ...   ...
# 25187         0           tcp      exec  RSTO          0          0     0
# 25188         0           tcp  ftp_data    SF        334          0     0
# 25189         0           tcp   private   REJ          0          0     0
# 25190         0           tcp      nnsp    S0          0          0     0
# 25191         0           tcp    finger    S0          0          0     0
#
#        wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# ...

# %%
df_train.head()
# Out:
#    duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 0         0           tcp  ftp_data   SF        491          0     0
# 1         0           udp     other   SF        146          0     0
# 2         0           tcp   private   S0          0          0     0
# 3         0           tcp      http   SF        232       8153     0
# 4         0           tcp      http   SF        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0               0       0    0  ...                  25
# 1               0       0    0  ...                   1
# 2               0       0    0  ...                  26
# 3               0       0    0  ...                 255
# 4               0       0    0  ...                 255
#
#    dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    0.17                    0.03
# 1                    0.00                    0.60
# 2                    0.10                    0.05
# ...

# %%
df_train.tail()
# Out:
#        duration protocol_type   service  flag  src_bytes  dst_bytes  land  \
# 25187         0           tcp      exec  RSTO          0          0     0
# 25188         0           tcp  ftp_data    SF        334          0     0
# 25189         0           tcp   private   REJ          0          0     0
# 25190         0           tcp      nnsp    S0          0          0     0
# 25191         0           tcp    finger    S0          0          0     0
#
#        wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 25187               0       0    0  ...                   7
# 25188               0       0    0  ...                  39
# 25189               0       0    0  ...                  13
# 25190               0       0    0  ...                  20
# 25191               0       0    0  ...                  49
#
#        dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 25187                    0.03                    0.06
# ...

# %%
df_train.shape
# Out:
# (25192, 42)

# %%
df_train.columns
# Out:
# Index(['duration', 'protocol_type', 'service', 'flag', 'src_bytes',
#        'dst_bytes', 'land', 'wrong_fragment', 'urgent', 'hot',
#        'num_failed_logins', 'logged_in', 'num_compromised', 'root_shell',
#        'su_attempted', 'num_root', 'num_file_creations', 'num_shells',
#        'num_access_files', 'num_outbound_cmds', 'is_host_login',
#        'is_guest_login', 'count', 'srv_count', 'serror_rate',
#        'srv_serror_rate', 'rerror_rate', 'srv_rerror_rate', 'same_srv_rate',
#        'diff_srv_rate', 'srv_diff_host_rate', 'dst_host_count',
#        'dst_host_srv_count', 'dst_host_same_srv_rate',
#        'dst_host_diff_srv_rate', 'dst_host_same_src_port_rate',
#        'dst_host_srv_diff_host_rate', 'dst_host_serror_rate',
#        'dst_host_srv_serror_rate', 'dst_host_rerror_rate',
#        'dst_host_srv_rerror_rate', 'class'],
#       dtype='object')

# %%
df_train.isna().sum()
# Out:
# duration                       0
# protocol_type                  0
# service                        0
# flag                           0
# src_bytes                      0
# dst_bytes                      0
# land                           0
# wrong_fragment                 0
# urgent                         0
# hot                            0
# num_failed_logins              0
# logged_in                      0
# num_compromised                0
# root_shell                     0
# su_attempted                   0
# num_root                       0
# num_file_creations             0
# num_shells                     0
# num_access_files               0
# num_outbound_cmds              0
# is_host_login                  0
# is_guest_login                 0
# count                          0
# srv_count                      0
# serror_rate                    0
# srv_serror_rate                0
# rerror_rate                    0
# srv_rerror_rate                0
# ...

# %%
df_train.dtypes
# Out:
# duration                         int64
# protocol_type                   object
# service                         object
# flag                            object
# src_bytes                        int64
# dst_bytes                        int64
# land                             int64
# wrong_fragment                   int64
# urgent                           int64
# hot                              int64
# num_failed_logins                int64
# logged_in                        int64
# num_compromised                  int64
# root_shell                       int64
# su_attempted                     int64
# num_root                         int64
# num_file_creations               int64
# num_shells                       int64
# num_access_files                 int64
# num_outbound_cmds                int64
# is_host_login                    int64
# is_guest_login                   int64
# count                            int64
# srv_count                        int64
# ...

# %%
#object data visualizations

v1=df_train['protocol_type'].value_counts()
v1
# Out:
# protocol_type
# tcp     20526
# udp      3011
# icmp     1655
# Name: count, dtype: int64

# %%
plt.bar(v1.index,v1.values,color='skyblue')
plt.title('Protocol Value Counts')
# Out:
# Text(0.5, 1.0, 'Protocol Value Counts')

# %%
v2=df_train['service'].value_counts()[:10]
v2
# Out:
# service
# http        8003
# private     4351
# domain_u    1820
# smtp        1449
# ftp_data    1396
# eco_i        909
# other        858
# ecr_i        613
# telnet       483
# finger       366
# Name: count, dtype: int64

# %%
plt.barh(v2.index,v2.values,color='brown')
plt.title('Service Value Counts')
# Out:
# Text(0.5, 1.0, 'Service Value Counts')

# %%
v3=df_train['flag'].value_counts()
v3
# Out:
# flag
# SF        14973
# S0         7009
# REJ        2216
# RSTR        497
# RSTO        304
# S1           88
# SH           43
# RSTOS0       21
# S2           21
# S3           15
# OTH           5
# Name: count, dtype: int64

# %%
plt.bar(v3.index,v3.values,color='green')
plt.title('Flag Value Counts')
# Out:
# Text(0.5, 1.0, 'Flag Value Counts')

# %%
v4=df_train['class'].value_counts()
v4
# Out:
# class
# normal     13449
# anomaly    11743
# Name: count, dtype: int64

# %%
plt.bar(v4.index,v4.values,color=['orange','blue'])
plt.title('Attack Type Distribution')
# Out:
# Text(0.5, 1.0, 'Attack Type Distribution')

# %%
df_train.duplicated().sum()
# Out:
# 0

# %%
#Encoding for categorical columns
#Label Encoding

from sklearn.preprocessing import LabelEncoder

lab=LabelEncoder()
df_train['protocol_type']=lab.fit_transform(df_train['protocol_type'])
df_train['flag']=lab.fit_transform(df_train['flag'])
df_train['service']=lab.fit_transform(df_train['service'])

df_train
# Out:
#        duration  protocol_type  service  flag  src_bytes  dst_bytes  land  \
# 0             0              1       19     9        491          0     0
# 1             0              2       41     9        146          0     0
# 2             0              1       46     5          0          0     0
# 3             0              1       22     9        232       8153     0
# 4             0              1       22     9        199        420     0
# ...         ...            ...      ...   ...        ...        ...   ...
# 25187         0              1       16     2          0          0     0
# 25188         0              1       19     9        334          0     0
# 25189         0              1       46     1          0          0     0
# 25190         0              1       38     5          0          0     0
# 25191         0              1       17     5          0          0     0
#
#        wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# ...

# %%
df_train.dtypes
# Out:
# duration                         int64
# protocol_type                    int32
# service                          int32
# flag                             int32
# src_bytes                        int64
# dst_bytes                        int64
# land                             int64
# wrong_fragment                   int64
# urgent                           int64
# hot                              int64
# num_failed_logins                int64
# logged_in                        int64
# num_compromised                  int64
# root_shell                       int64
# su_attempted                     int64
# num_root                         int64
# num_file_creations               int64
# num_shells                       int64
# num_access_files                 int64
# num_outbound_cmds                int64
# is_host_login                    int64
# is_guest_login                   int64
# count                            int64
# srv_count                        int64
# ...

# %%
#correlation matrix

num_df=df_train.select_dtypes(include=[np.number])

plt.figure(figsize=(30,30))
sb.heatmap(num_df.corr(), cmap="coolwarm", annot=True)
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
#drop columns

cols_to_drop = [
    "num_outbound_cmds", 
    "is_host_login", 
    "dst_host_same_srv_rate", 
    "same_srv_rate", 
    "dst_host_srv_diff_host_rate"
]

df_train.drop(columns=cols_to_drop, inplace=True)
df_train
# Out:
#        duration  protocol_type  service  flag  src_bytes  dst_bytes  land  \
# 0             0              1       19     9        491          0     0
# 1             0              2       41     9        146          0     0
# 2             0              1       46     5          0          0     0
# 3             0              1       22     9        232       8153     0
# 4             0              1       22     9        199        420     0
# ...         ...            ...      ...   ...        ...        ...   ...
# 25187         0              1       16     2          0          0     0
# 25188         0              1       19     9        334          0     0
# 25189         0              1       46     1          0          0     0
# 25190         0              1       38     5          0          0     0
# 25191         0              1       17     5          0          0     0
#
#        wrong_fragment  urgent  hot  ...  srv_diff_host_rate  dst_host_count  \
# ...

# %%
df_train.columns
# Out:
# Index(['duration', 'protocol_type', 'service', 'flag', 'src_bytes',
#        'dst_bytes', 'land', 'wrong_fragment', 'urgent', 'hot',
#        'num_failed_logins', 'logged_in', 'num_compromised', 'root_shell',
#        'su_attempted', 'num_root', 'num_file_creations', 'num_shells',
#        'num_access_files', 'is_guest_login', 'count', 'srv_count',
#        'serror_rate', 'srv_serror_rate', 'rerror_rate', 'srv_rerror_rate',
#        'diff_srv_rate', 'srv_diff_host_rate', 'dst_host_count',
#        'dst_host_srv_count', 'dst_host_diff_srv_rate',
#        'dst_host_same_src_port_rate', 'dst_host_serror_rate',
#        'dst_host_srv_serror_rate', 'dst_host_rerror_rate',
#        'dst_host_srv_rerror_rate', 'class'],
#       dtype='object')

# %%
#normalization

# from sklearn.preprocessing import StandardScaler

# sc=StandardScaler()
# df_train['src_bytes']=sc.fit_transform(df_train[['src_bytes']])
# df_train

# %%
y=df_train['class'].values
y
# Out:
# array(['normal', 'normal', 'anomaly', ..., 'anomaly', 'anomaly',
#        'anomaly'], dtype=object)

# %%
x=df_train.drop(['class'],axis=1)
x
# Out:
#        duration  protocol_type  service  flag  src_bytes  dst_bytes  land  \
# 0             0              1       19     9        491          0     0
# 1             0              2       41     9        146          0     0
# 2             0              1       46     5          0          0     0
# 3             0              1       22     9        232       8153     0
# 4             0              1       22     9        199        420     0
# ...         ...            ...      ...   ...        ...        ...   ...
# 25187         0              1       16     2          0          0     0
# 25188         0              1       19     9        334          0     0
# 25189         0              1       46     1          0          0     0
# 25190         0              1       38     5          0          0     0
# 25191         0              1       17     5          0          0     0
#
#        wrong_fragment  urgent  hot  ...  diff_srv_rate  srv_diff_host_rate  \
# ...

# %%
x.columns
# Out:
# Index(['duration', 'protocol_type', 'service', 'flag', 'src_bytes',
#        'dst_bytes', 'land', 'wrong_fragment', 'urgent', 'hot',
#        'num_failed_logins', 'logged_in', 'num_compromised', 'root_shell',
#        'su_attempted', 'num_root', 'num_file_creations', 'num_shells',
#        'num_access_files', 'is_guest_login', 'count', 'srv_count',
#        'serror_rate', 'srv_serror_rate', 'rerror_rate', 'srv_rerror_rate',
#        'diff_srv_rate', 'srv_diff_host_rate', 'dst_host_count',
#        'dst_host_srv_count', 'dst_host_diff_srv_rate',
#        'dst_host_same_src_port_rate', 'dst_host_serror_rate',
#        'dst_host_srv_serror_rate', 'dst_host_rerror_rate',
#        'dst_host_srv_rerror_rate'],
#       dtype='object')

# %%
df_test=pd.read_csv('Test_data.csv')
df_test
# Out:
#        duration protocol_type   service  flag  src_bytes  dst_bytes  land  \
# 0             0           tcp   private   REJ          0          0     0
# 1             0           tcp   private   REJ          0          0     0
# 2             2           tcp  ftp_data    SF      12983          0     0
# 3             0          icmp     eco_i    SF         20          0     0
# 4             1           tcp    telnet  RSTO          0         15     0
# ...         ...           ...       ...   ...        ...        ...   ...
# 22539         0           tcp      smtp    SF        794        333     0
# 22540         0           tcp      http    SF        317        938     0
# 22541         0           tcp      http    SF      54540       8314     0
# 22542         0           udp  domain_u    SF         42         42     0
# 22543         0           tcp    sunrpc   REJ          0          0     0
#
#        wrong_fragment  urgent  hot  ...  dst_host_count  dst_host_srv_count  \
# ...

# %%
df_test.head()
# Out:
#    duration protocol_type   service  flag  src_bytes  dst_bytes  land  \
# 0         0           tcp   private   REJ          0          0     0
# 1         0           tcp   private   REJ          0          0     0
# 2         2           tcp  ftp_data    SF      12983          0     0
# 3         0          icmp     eco_i    SF         20          0     0
# 4         1           tcp    telnet  RSTO          0         15     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_count  dst_host_srv_count  \
# 0               0       0    0  ...             255                  10
# 1               0       0    0  ...             255                   1
# 2               0       0    0  ...             134                  86
# 3               0       0    0  ...               3                  57
# 4               0       0    0  ...              29                  86
#
#    dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    0.04                    0.06
# ...

# %%
df_test.tail()
# Out:
#        duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 22539         0           tcp      smtp   SF        794        333     0
# 22540         0           tcp      http   SF        317        938     0
# 22541         0           tcp      http   SF      54540       8314     0
# 22542         0           udp  domain_u   SF         42         42     0
# 22543         0           tcp    sunrpc  REJ          0          0     0
#
#        wrong_fragment  urgent  hot  ...  dst_host_count  dst_host_srv_count  \
# 22539               0       0    0  ...             100                 141
# 22540               0       0    0  ...             197                 255
# 22541               0       0    2  ...             255                 255
# 22542               0       0    0  ...             255                 252
# 22543               0       0    0  ...             255                  21
#
#        dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# ...

# %%
df_test.shape
# Out:
# (22544, 41)

# %%
df_test.columns
# Out:
# Index(['duration', 'protocol_type', 'service', 'flag', 'src_bytes',
#        'dst_bytes', 'land', 'wrong_fragment', 'urgent', 'hot',
#        'num_failed_logins', 'logged_in', 'num_compromised', 'root_shell',
#        'su_attempted', 'num_root', 'num_file_creations', 'num_shells',
#        'num_access_files', 'num_outbound_cmds', 'is_host_login',
#        'is_guest_login', 'count', 'srv_count', 'serror_rate',
#        'srv_serror_rate', 'rerror_rate', 'srv_rerror_rate', 'same_srv_rate',
#        'diff_srv_rate', 'srv_diff_host_rate', 'dst_host_count',
#        'dst_host_srv_count', 'dst_host_same_srv_rate',
#        'dst_host_diff_srv_rate', 'dst_host_same_src_port_rate',
#        'dst_host_srv_diff_host_rate', 'dst_host_serror_rate',
#        'dst_host_srv_serror_rate', 'dst_host_rerror_rate',
#        'dst_host_srv_rerror_rate'],
#       dtype='object')

# %%
df_test.isna().sum()
# Out:
# duration                       0
# protocol_type                  0
# service                        0
# flag                           0
# src_bytes                      0
# dst_bytes                      0
# land                           0
# wrong_fragment                 0
# urgent                         0
# hot                            0
# num_failed_logins              0
# logged_in                      0
# num_compromised                0
# root_shell                     0
# su_attempted                   0
# num_root                       0
# num_file_creations             0
# num_shells                     0
# num_access_files               0
# num_outbound_cmds              0
# is_host_login                  0
# is_guest_login                 0
# count                          0
# srv_count                      0
# serror_rate                    0
# srv_serror_rate                0
# rerror_rate                    0
# srv_rerror_rate                0
# ...

# %%
df_test.dtypes
# Out:
# duration                         int64
# protocol_type                   object
# service                         object
# flag                            object
# src_bytes                        int64
# dst_bytes                        int64
# land                             int64
# wrong_fragment                   int64
# urgent                           int64
# hot                              int64
# num_failed_logins                int64
# logged_in                        int64
# num_compromised                  int64
# root_shell                       int64
# su_attempted                     int64
# num_root                         int64
# num_file_creations               int64
# num_shells                       int64
# num_access_files                 int64
# num_outbound_cmds                int64
# is_host_login                    int64
# is_guest_login                   int64
# count                            int64
# srv_count                        int64
# ...

# %%
#visualization on test data

v5=df_test['protocol_type'].value_counts()
v5
# Out:
# protocol_type
# tcp     18880
# udp      2621
# icmp     1043
# Name: count, dtype: int64

# %%
plt.bar(v5.index,v5.values)
plt.title('Protocol Type Distribution')
# Out:
# Text(0.5, 1.0, 'Protocol Type Distribution')

# %%
v6=df_test['service'].value_counts()[:10]
v6
# Out:
# service
# http        7853
# private     4774
# telnet      1626
# pop_3       1019
# smtp         934
# domain_u     894
# ftp_data     851
# other        838
# ecr_i        752
# ftp          692
# Name: count, dtype: int64

# %%
plt.barh(v6.index,v6.values,color='k')
plt.title('Service Distribution')
# Out:
# Text(0.5, 1.0, 'Service Distribution')

# %%
v7=df_test['flag'].value_counts()
v7
# Out:
# flag
# SF        14875
# REJ        3850
# S0         2013
# RSTO        773
# RSTR        669
# S3          249
# SH           73
# S1           21
# S2           15
# OTH           4
# RSTOS0        2
# Name: count, dtype: int64

# %%
plt.bar(v7.index,v7.values,color='purple')
plt.title('Flag Value Distribution')
# Out:
# Text(0.5, 1.0, 'Flag Value Distribution')

# %%
df_test.duplicated().sum()
# Out:
# 57

# %%
df_test.drop_duplicates()
# Out:
#        duration protocol_type   service  flag  src_bytes  dst_bytes  land  \
# 0             0           tcp   private   REJ          0          0     0
# 1             0           tcp   private   REJ          0          0     0
# 2             2           tcp  ftp_data    SF      12983          0     0
# 3             0          icmp     eco_i    SF         20          0     0
# 4             1           tcp    telnet  RSTO          0         15     0
# ...         ...           ...       ...   ...        ...        ...   ...
# 22539         0           tcp      smtp    SF        794        333     0
# 22540         0           tcp      http    SF        317        938     0
# 22541         0           tcp      http    SF      54540       8314     0
# 22542         0           udp  domain_u    SF         42         42     0
# 22543         0           tcp    sunrpc   REJ          0          0     0
#
#        wrong_fragment  urgent  hot  ...  dst_host_count  dst_host_srv_count  \
# ...

# %%
df_test.shape
# Out:
# (22544, 41)

# %%
#encoding
df_test['protocol_type']=lab.fit_transform(df_test['protocol_type'])
df_test['flag']=lab.fit_transform(df_test['flag'])
df_test['service']=lab.fit_transform(df_test['service'])

df_test
# Out:
#        duration  protocol_type  service  flag  src_bytes  dst_bytes  land  \
# 0             0              1       45     1          0          0     0
# 1             0              1       45     1          0          0     0
# 2             2              1       19     9      12983          0     0
# 3             0              0       13     9         20          0     0
# 4             1              1       55     2          0         15     0
# ...         ...            ...      ...   ...        ...        ...   ...
# 22539         0              1       49     9        794        333     0
# 22540         0              1       22     9        317        938     0
# 22541         0              1       22     9      54540       8314     0
# 22542         0              2       11     9         42         42     0
# 22543         0              1       52     1          0          0     0
#
#        wrong_fragment  urgent  hot  ...  dst_host_count  dst_host_srv_count  \
# ...

# %%
df_test.drop(columns=cols_to_drop,inplace=True)
df_test
# Out:
#        duration  protocol_type  service  flag  src_bytes  dst_bytes  land  \
# 0             0              1       45     1          0          0     0
# 1             0              1       45     1          0          0     0
# 2             2              1       19     9      12983          0     0
# 3             0              0       13     9         20          0     0
# 4             1              1       55     2          0         15     0
# ...         ...            ...      ...   ...        ...        ...   ...
# 22539         0              1       49     9        794        333     0
# 22540         0              1       22     9        317        938     0
# 22541         0              1       22     9      54540       8314     0
# 22542         0              2       11     9         42         42     0
# 22543         0              1       52     1          0          0     0
#
#        wrong_fragment  urgent  hot  ...  diff_srv_rate  srv_diff_host_rate  \
# ...

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=1)
x_train
# Out:
# array([[ 0.,  0., 13., ...,  0.,  0.,  0.],
#        [ 0.,  1., 22., ...,  0.,  0.,  0.],
#        [ 0.,  0., 14., ...,  0.,  0.,  0.],
#        ...,
#        [ 0.,  1., 46., ...,  1.,  0.,  0.],
#        [ 0.,  1., 22., ...,  0.,  0.,  0.],
#        [ 0.,  1., 18., ...,  0.,  1.,  1.]])

# %%
from sklearn.ensemble import RandomForestClassifier

model=RandomForestClassifier(n_estimators=100)
model.fit(x_train,y_train)

y_pred=model.predict(x_test)
y_pred
# Out:
# array(['anomaly', 'normal', 'anomaly', ..., 'normal', 'normal', 'normal'],
#       dtype=object)

# %%
from sklearn.metrics import accuracy_score,classification_report

sc=accuracy_score(y_test,y_pred)
sc
# Out:
# 0.9977507277057422

# %%
rpt=classification_report(y_test,y_pred)
rpt
# Out:
# '              precision    recall  f1-score   support\n\n     anomaly       1.00      1.00      1.00      3507\n      normal       1.00      1.00      1.00      4051\n\n    accuracy                           1.00      7558\n   macro avg       1.00      1.00      1.00      7558\nweighted avg       1.00      1.00      1.00      7558\n'

# %%
x_test2=df_test.values
x_test2
# Out:
# array([[ 0.  ,  1.  , 45.  , ...,  0.  ,  1.  ,  1.  ],
#        [ 0.  ,  1.  , 45.  , ...,  0.  ,  1.  ,  1.  ],
#        [ 2.  ,  1.  , 19.  , ...,  0.  ,  0.  ,  0.  ],
#        ...,
#        [ 0.  ,  1.  , 22.  , ...,  0.  ,  0.07,  0.07],
#        [ 0.  ,  2.  , 11.  , ...,  0.  ,  0.  ,  0.  ],
#        [ 0.  ,  1.  , 52.  , ...,  0.  ,  0.44,  1.  ]])

# %%
y_pred2=model.predict(x_test2)
y_pred2
# Out:
# array(['anomaly', 'anomaly', 'normal', ..., 'anomaly', 'normal',
#        'anomaly'], dtype=object)

# %%
import joblib

joblib.dump(model, 'model.pkl')
# Out:
# ['model.pkl']
